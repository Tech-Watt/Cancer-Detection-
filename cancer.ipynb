# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# Reading the dataset

# %%
data = pd.read_csv("cancer data.csv")

# %% [markdown]
# Exploring the datasets to select our features and targets

# %%
data.head(6)
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
# 5      5       P102   35       1              4            5             6
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# ...

# %%
data.columns
# Out:
# Index(['index', 'Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1000 non-null   int64
#  1   Patient Id                1000 non-null   object
#  2   Age                       1000 non-null   int64
#  3   Gender                    1000 non-null   int64
#  4   Air Pollution             1000 non-null   int64
#  5   Alcohol use               1000 non-null   int64
#  6   Dust Allergy              1000 non-null   int64
#  7   OccuPational Hazards      1000 non-null   int64
#  8   Genetic Risk              1000 non-null   int64
#  9   chronic Lung Disease      1000 non-null   int64
#  10  Balanced Diet             1000 non-null   int64
#  11  Obesity                   1000 non-null   int64
#  12  Smoking                   1000 non-null   int64
#  13  Passive Smoker            1000 non-null   int64
# ...

# %%
data.dtypes
# Out:
# index                        int64
# Patient Id                  object
# Age                          int64
# Gender                       int64
# Air Pollution                int64
# Alcohol use                  int64
# Dust Allergy                 int64
# OccuPational Hazards         int64
# Genetic Risk                 int64
# chronic Lung Disease         int64
# Balanced Diet                int64
# Obesity                      int64
# Smoking                      int64
# Passive Smoker               int64
# Chest Pain                   int64
# Coughing of Blood            int64
# Fatigue                      int64
# Weight Loss                  int64
# Shortness of Breath          int64
# Wheezing                     int64
# Swallowing Difficulty        int64
# Clubbing of Finger Nails     int64
# Frequent Cold                int64
# Dry Cough                    int64
# Snoring                      int64
# Level                       object
# dtype: object

# %%
data.shape
# Out:
# (1000, 26)

# %%
data.isnull().sum()
# Out:
# index                       0
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
data.isna().sum()
# Out:
# index                       0
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %% [markdown]
# Performing Descriptive Statistics on the dataset

# %%
data.describe().T
# Out:
#                            count     mean         std   min     25%    50%  \
# index                     1000.0  499.500  288.819436   0.0  249.75  499.5
# Age                       1000.0   37.174   12.005493  14.0   27.75   36.0
# Gender                    1000.0    1.402    0.490547   1.0    1.00    1.0
# Air Pollution             1000.0    3.840    2.030400   1.0    2.00    3.0
# Alcohol use               1000.0    4.563    2.620477   1.0    2.00    5.0
# Dust Allergy              1000.0    5.165    1.980833   1.0    4.00    6.0
# OccuPational Hazards      1000.0    4.840    2.107805   1.0    3.00    5.0
# Genetic Risk              1000.0    4.580    2.126999   1.0    2.00    5.0
# chronic Lung Disease      1000.0    4.380    1.848518   1.0    3.00    4.0
# Balanced Diet             1000.0    4.491    2.135528   1.0    2.00    4.0
# Obesity                   1000.0    4.465    2.124921   1.0    3.00    4.0
# ...

# %% [markdown]
# Final engineered dataset to work with.

# %%
final_data_columns = ['Age', 'Gender', 'Smoking', 'Genetic Risk', 'Obesity', 
                'chronic Lung Disease', 'Alcohol use', 'OccuPational Hazards', 
                'Passive Smoker','Level']

# %%
final_data = data[final_data_columns]
final_data.head()
# Out:
#    Age  Gender  Smoking  Genetic Risk  Obesity  chronic Lung Disease  \
# 0   33       1        3             3        4                     2
# 1   17       1        2             4        2                     2
# 2   35       1        2             5        7                     4
# 3   37       1        7             6        7                     7
# 4   46       1        8             7        7                     6
#
#    Alcohol use  OccuPational Hazards  Passive Smoker   Level
# 0            4                     4               2     Low
# 1            1                     3               4  Medium
# 2            5                     5               3    High
# 3            7                     7               7    High
# 4            8                     7               7    High

# %%
final_data.to_csv('cancer.csv',index=False)

# %% [markdown]
# Visualization

# %%
color = 'winter'
fig,axes = plt.subplots(4,2,figsize=(20,30))

sns.barplot(ax = axes[0,0],x ='Gender',y ='Smoking',data =final_data,)
axes[0,0].set_title('Gender and their coresponding smoking levels')
sns.barplot(ax = axes[0,1],x ='Gender',y ='Smoking',data =final_data,hue='Level',palette=color)
axes[0,1].set_title('Gender and their coresponding smoking levels from low,medium and high')

sns.barplot(ax=axes[1,0],x ='Gender',y ='Alcohol use',data =final_data,hue='Gender',palette=color)
axes[1,0].set_title('Gender vs Alcohol Intake ')
sns.barplot(ax = axes[1,1],x ='Gender',y ='Alcohol use',data =final_data,hue='Level',palette=color)
axes[1,1].set_title('Gender and the their alcohol levels from low,medium and high')

sns.barplot(ax=axes[2,0],x ='Gender',y ='Age',data =final_data,hue='Gender',palette=color)
axes[2,0].set_title('Gender vs Age ')
sns.barplot(ax = axes[2,1],x ='Gender',y ='Age',data =final_data,hue='Level',palette=color)
axes[2,1].set_title('Gender and the their ages levels from low,medium and high')

sns.barplot(ax=axes[3,0],x ='Gender',y ='Obesity',data =final_data,hue='Gender',palette=color)
axes[3,0].set_title('Gender vs Obesity')
sns.barplot(ax = axes[3,1],x ='Gender',y ='Obesity',data =final_data,hue='Level',palette=color)
axes[3,1].set_title('Gender and the their Obesity levels from low,medium and high')


plt.show()

# %%
fig,axes = plt.subplots(4,2,figsize=(25,30))

sns.barplot(ax=axes[0,0],x ='Gender',y ='Genetic Risk',data =final_data,hue='Gender',palette=color)
axes[0,0].set_title('Gender vs Genetic Risk')
sns.barplot(ax = axes[0,1],x ='Gender',y ='Genetic Risk',data =final_data,hue='Level',palette=color)
axes[0,1].set_title('Gender and the their Genetic Risk levels from low,medium and high')

sns.barplot(ax=axes[1,0],x ='Gender',y ='chronic Lung Disease',data =final_data,hue='Gender',palette=color)
axes[1,0].set_title('Gender vs chronic Lung Disease')
sns.barplot(ax = axes[1,1],x ='Gender',y ='chronic Lung Disease',data =final_data,hue='Level',palette=color)
axes[1,1].set_title('Gender and the their chronic Lung Disease levels from low,medium and high')

sns.barplot(ax=axes[2,0],x ='Gender',y ='OccuPational Hazards',data =final_data,hue='Gender',palette=color)
axes[2,0].set_title('Gender vs OccuPational Hazards')
sns.barplot(ax = axes[2,1],x ='Gender',y ='OccuPational Hazards',data =final_data,hue='Level',palette=color)
axes[2,1].set_title('Gender and the their OccuPational Hazards levels from low,medium and high')

sns.barplot(ax=axes[3,0],x ='Gender',y ='Passive Smoker',data =final_data,hue='Gender',palette=color)
axes[3,0].set_title('Gender vs Passive Smoker')
sns.barplot(ax = axes[3,1],x ='Gender',y ='Passive Smoker',data =final_data,hue='Level',palette=color)
axes[3,1].set_title('Gender and the their Passive Smoker levels from low,medium and high')
# Out:
# Text(0.5, 1.0, 'Gender and the their Passive Smoker levels from low,medium and high')

# %%
plt.title('Category with the highest cancer between Low, Medium and High')
sns.countplot(data = final_data,x='Level',palette='rocket_r',hue='Level')
plt.show()

# %% [markdown]
# Creating the Machine learning model

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import numpy as np

# %% [markdown]
# Separating data into features and targets and Spliting into training and testing set

# %%
features = final_data.drop('Level', axis=1)
target_data = final_data['Level']

target_data = np.array([ 0 if x == 'Low' else 1 if x == 'Medium' 
                        else 2 for x in target_data])

X_train,X_test,Y_train,Y_test = train_test_split(features,target_data,
        random_state=42,test_size=0.20)

# %% [markdown]
# LOW = 0
# MEDIUM = 1
# HIGH = 2

# %% [markdown]
# Building a preprocessing,model pipeline and training the model.

# %%
pipeline = Pipeline([
    ('scaler',StandardScaler()),
    # ('model',LinearRegression()),
    ('randomforest',RandomForestClassifier(n_estimators=100)),
])

pipeline.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('randomforest', RandomForestClassifier())])

# %% [markdown]
# Evaluating the trained model on the Test dataset

# %%
y_pred = pipeline.predict(X_test)
mae = mean_absolute_error(Y_test, y_pred)
mse = mean_squared_error(Y_test, y_pred)
print(f'Mean absolute error: {mae}')
print(f'Mean squared error: {mse}')
# Out:
# Mean absolute error: 0.005
# Mean squared error: 0.005

# %% [markdown]
# Visualizing the output

# %%
# Create a DataFrame with the true and predicted values
data = {'True Values': Y_test, 'Predicted Values': y_pred}
df = pd.DataFrame(data)

# Create the scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Predicted Values', y='True Values', data=df)
plt.plot([df['True Values'].min(), df['True Values'].max()], [df['True Values'].min(), df['True Values'].max()], 'r--', lw=2)
plt.xlabel('Predicted Values')
plt.ylabel('True Values')
plt.title('Scatter Plot of True vs Predicted Values')
plt.show()

# %% [markdown]
# Testing on custom data

# %%
custom_test_data = np.array([17,1,2,4,2,2,1,3,4])
result = pipeline.predict([custom_test_data])
print(f'Your prediction is: {result}')
# Out:
# Your prediction is: [1]
